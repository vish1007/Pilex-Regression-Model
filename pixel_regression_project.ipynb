# %% [markdown]
# # Pixel Localization with CNN
#
# ## Problem Description
# In this project, we aim to build a Convolutional Neural Network (CNN) that predicts the exact (x, y) coordinate of a single white pixel (value 255) placed on a black 50x50 image. This is a regression problem where the model learns to infer the spatial position of a visual cue.

# %% [markdown]
# ## Installation & Dependencies

# %%
# === Import Required Libraries ===
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np
from torchsummary import summary
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# === Set Random Seed for Reproducibility ===
np.random.seed(42)
torch.manual_seed(42)

# %% [markdown]
# ## Dataset Generation

# %% [markdown]
# The dataset is designed to predict the (x, y) coordinates of a white pixel placed in a black 50x50 image.
#
# - **Data Generation**: The white pixel is placed at all possible positions in the grid (from (0,0) to (49,49)), resulting in 2500 unique images. Each image is normalized to a range of [0, 1], and the target coordinates (x, y) are also scaled similarly.
#
# - **No Data Leakage**: The dataset is split into training, validation, and test sets (70%, 15%, 15%). There is no overlap between the sets, ensuring that the model doesn't "cheat" by seeing validation or test data during training.
#
# - **Balanced Distribution**: The white pixel is evenly distributed across all positions in the grid, ensuring the model learns to predict any (x, y) location without any bias toward specific areas of the image.
# This setup avoids data leakage and ensures the model generalizes well across the entire image.
#
# - **Normalization**:The pixel values are normalized to the range [0, 1] by dividing by 255. This ensures that the model receives values in a consistent range that is easier to process during training.Similarly, the target coordinates [x, y] are normalized by dividing by the maximum value of the coordinate (49 in this case), scaling the target coordinates into the range [0, 1]. This helps in smoother optimization and avoids large gradient values during training.

# %%
# === Function to Generate Dataset ===
def generate_full_dataset(image_size=50):
    """
    Generates a dataset of images with one white pixel (value 255)
    at every possible (x, y) location in a grayscale image.

    Args:
        image_size (int): Height/width of square image (default: 50)

    Returns:
        torch.Tensor: Images of shape (N, 1, H, W)
        torch.Tensor: Corresponding normalized (x, y) coordinates
    """
    X, Y = [], []
    for x in range(image_size):
        for y in range(image_size):
            img = np.zeros((image_size, image_size), dtype=np.uint8)
            img[y, x] = 255  # Set one white pixel
            X.append(img / 255.0)  # Normalize to 0-1
            Y.append([x / 49.0, y / 49.0])  # Normalize coordinates to [0, 1]

    X = np.array(X).reshape(-1, 1, image_size, image_size).astype(np.float32)
    Y = np.array(Y).astype(np.float32)

    return torch.tensor(X), torch.tensor(Y)

# === Generate Dataset ===
X, Y = generate_full_dataset(image_size=50)

# %% [markdown]
# ## 🧩 Data Splitting & Visualization -Distribution of training,validation and test

# %%
# === Split the Data ===
# First, split the dataset into training and temporary (val + test)
X_train, X_temp, Y_train, Y_temp = train_test_split(
    X, Y, test_size=0.3, random_state=42
)

# Then split the temp into validation and test sets
X_val, X_test, Y_val, Y_test = train_test_split(
    X_temp, Y_temp, test_size=0.5, random_state=42
)

# === Create TensorDatasets ===
train_ds = TensorDataset(X_train, Y_train)
val_ds = TensorDataset(X_val, Y_val)
test_ds = TensorDataset(X_test, Y_test)

# === Create DataLoaders ===
train_loader = DataLoader(train_ds, batch_size=64, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=64)
test_loader = DataLoader(test_ds, batch_size=64)

# === Pixel Distribution Visualization Function ===
def plot_pixel_distribution(X_tensor, title):
    """
    Plots a heatmap showing the distribution of white pixels
    in the dataset.

    Args:
        X_tensor (torch.Tensor): Dataset tensor of shape (N, 1, H, W)
        title (str): Title for the heatmap plot
    """
    heatmap = torch.sum(X_tensor, dim=0).squeeze().numpy()

    plt.figure(figsize=(5, 5))
    plt.imshow(heatmap, cmap='hot')
    plt.title(title)
    plt.colorbar(label='Pixel Overlap Count')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.gca().invert_yaxis()
    plt.grid(False)
    plt.show()

# === Plot Pixel Distributions ===
plot_pixel_distribution(X_train, "Train Pixel Distribution")
plot_pixel_distribution(X_val, "Validation Pixel Distribution")
plot_pixel_distribution(X_test, "Test Pixel Distribution")

# %% [markdown]
# ## 🏗️ Model Architecture

# %%
import torch.nn as nn
import torch

# === Define the CNN Model for Pixel Coordinate Regression ===
class PixelRegressor(nn.Module):
    """
    A simple CNN that takes a 50x50 grayscale image with a single white pixel
    and predicts its (x, y) coordinates as normalized values.
    """
    def __init__(self):
        super(PixelRegressor, self).__init__()

        self.net = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=16, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),

            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),

            nn.Flatten(),

            nn.Linear(in_features=32 * 11 * 11, out_features=64),
            nn.ReLU(),
            

            nn.Linear(in_features=64, out_features=2)
        )

    def forward(self, x):
        return self.net(x)

# === Device Configuration ===
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

if device.type == 'cuda':
    print(f"CUDA device name: {torch.cuda.get_device_name(0)}")
    print(f"CUDA device count: {torch.cuda.device_count()}")
else:
    print("CUDA not available, using CPU.")

# === Instantiate and Move Model to Device ===
model = PixelRegressor().to(device)

# === Print Model Summary ===

summary(model, input_size=(1, 50, 50))
# Out:
# Using device: cuda
# CUDA device name: NVIDIA T400 4GB
# CUDA device count: 1
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 48, 48]             160
#               ReLU-2           [-1, 16, 48, 48]               0
#          MaxPool2d-3           [-1, 16, 24, 24]               0
#             Conv2d-4           [-1, 32, 22, 22]           4,640
#               ReLU-5           [-1, 32, 22, 22]               0
#          MaxPool2d-6           [-1, 32, 11, 11]               0
#            Flatten-7                 [-1, 3872]               0
#             Linear-8                   [-1, 64]         247,872
#               ReLU-9                   [-1, 64]               0
#            Linear-10                    [-1, 2]             130
# ================================================================
# Total params: 252,802
# Trainable params: 252,802
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.93
# Params size (MB): 0.96
# Estimated Total Size (MB): 1.90
# ----------------------------------------------------------------

# %% [markdown]
# ## 🏃 Training the Model

# %%
# === Training Configuration ===
criterion = nn.MSELoss()                          # Mean Squared Error for regression
optimizer = optim.Adam(model.parameters(), lr=0.001)
early_stop_patience = 20                          # Number of epochs with no improvement before stopping

# === Training Function ===
def train_model(model, train_loader, val_loader, criterion, optimizer, epochs=300):
    """
    Train the CNN model with early stopping and return training and validation losses.

    Args:
        model (nn.Module): The neural network to train.
        train_loader (DataLoader): DataLoader for training data.
        val_loader (DataLoader): DataLoader for validation data.
        criterion: Loss function.
        optimizer: Optimization algorithm.
        epochs (int): Maximum number of training epochs.

    Returns:
        tuple: Lists of training and validation losses for each epoch.
    """
    best_val_loss = float('inf')
    patience_counter = 0
    train_losses, val_losses = [], []

    for epoch in range(epochs):
        model.train()
        epoch_train_loss = 0.0

        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            epoch_train_loss += loss.item() * X_batch.size(0)

        train_loss = epoch_train_loss / len(train_loader.dataset)
        train_losses.append(train_loss)

        # === Validation Phase ===
        model.eval()
        epoch_val_loss = 0.0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                epoch_val_loss += loss.item() * X_batch.size(0)

        val_loss = epoch_val_loss / len(val_loader.dataset)
        val_losses.append(val_loss)

        print(f"Epoch {epoch+1}: Train Loss = {train_loss:.5f}, Val Loss = {val_loss:.5f}")

        # === Early Stopping ===
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), "best_model.pth")  # Save best model weights
        else:
            patience_counter += 1
            if patience_counter >= early_stop_patience:
                print("Early stopping triggered.")
                break

    return train_losses, val_losses


# === Train the Model ===
train_losses, val_losses = train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer
)

# === Plot Training & Validation Loss Curve ===
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1: Train Loss = 0.11510, Val Loss = 0.08376
# Epoch 2: Train Loss = 0.08364, Val Loss = 0.07238
# Epoch 3: Train Loss = 0.05859, Val Loss = 0.03093
# Epoch 4: Train Loss = 0.02277, Val Loss = 0.01717
# Epoch 5: Train Loss = 0.01378, Val Loss = 0.01177
# Epoch 6: Train Loss = 0.01000, Val Loss = 0.01005
# Epoch 7: Train Loss = 0.00717, Val Loss = 0.00675
# Epoch 8: Train Loss = 0.00527, Val Loss = 0.00571
# Epoch 9: Train Loss = 0.00436, Val Loss = 0.00443
# Epoch 10: Train Loss = 0.00348, Val Loss = 0.00396
# Epoch 11: Train Loss = 0.00311, Val Loss = 0.00350
# Epoch 12: Train Loss = 0.00277, Val Loss = 0.00335
# Epoch 13: Train Loss = 0.00240, Val Loss = 0.00307
# Epoch 14: Train Loss = 0.00213, Val Loss = 0.00278
# Epoch 15: Train Loss = 0.00197, Val Loss = 0.00251
# Epoch 16: Train Loss = 0.00169, Val Loss = 0.00246
# Epoch 17: Train Loss = 0.00160, Val Loss = 0.00245
# Epoch 18: Train Loss = 0.00138, Val Loss = 0.00204
# Epoch 19: Train Loss = 0.00129, Val Loss = 0.00191
# Epoch 20: Train Loss = 0.00116, Val Loss = 0.00185
# Epoch 21: Train Loss = 0.00103, Val Loss = 0.00177
# Epoch 22: Train Loss = 0.00092, Val Loss = 0.00165
# Epoch 23: Train Loss = 0.00086, Val Loss = 0.00167
# Epoch 24: Train Loss = 0.00072, Val Loss = 0.00148
# Epoch 25: Train Loss = 0.00063, Val Loss = 0.00144
# Epoch 26: Train Loss = 0.00057, Val Loss = 0.00127
# Epoch 27: Train Loss = 0.00051, Val Loss = 0.00134
# Epoch 28: Train Loss = 0.00048, Val Loss = 0.00119
# Epoch 29: Train Loss = 0.00047, Val Loss = 0.00115
# Epoch 30: Train Loss = 0.00040, Val Loss = 0.00115
# Epoch 31: Train Loss = 0.00036, Val Loss = 0.00112
# Epoch 32: Train Loss = 0.00035, Val Loss = 0.00108
# Epoch 33: Train Loss = 0.00032, Val Loss = 0.00104
# Epoch 34: Train Loss = 0.00032, Val Loss = 0.00105
# Epoch 35: Train Loss = 0.00031, Val Loss = 0.00101
# Epoch 36: Train Loss = 0.00029, Val Loss = 0.00096
# Epoch 37: Train Loss = 0.00025, Val Loss = 0.00090
# Epoch 38: Train Loss = 0.00025, Val Loss = 0.00089
# Epoch 39: Train Loss = 0.00023, Val Loss = 0.00084
# Epoch 40: Train Loss = 0.00022, Val Loss = 0.00085
# Epoch 41: Train Loss = 0.00020, Val Loss = 0.00082
# Epoch 42: Train Loss = 0.00025, Val Loss = 0.00093
# Epoch 43: Train Loss = 0.00022, Val Loss = 0.00080
# Epoch 44: Train Loss = 0.00019, Val Loss = 0.00081
# Epoch 45: Train Loss = 0.00018, Val Loss = 0.00074
# Epoch 46: Train Loss = 0.00016, Val Loss = 0.00075
# Epoch 47: Train Loss = 0.00021, Val Loss = 0.00083
# Epoch 48: Train Loss = 0.00018, Val Loss = 0.00072
# Epoch 49: Train Loss = 0.00016, Val Loss = 0.00075
# Epoch 50: Train Loss = 0.00015, Val Loss = 0.00077
# Epoch 51: Train Loss = 0.00015, Val Loss = 0.00071
# Epoch 52: Train Loss = 0.00015, Val Loss = 0.00069
# Epoch 53: Train Loss = 0.00015, Val Loss = 0.00067
# Epoch 54: Train Loss = 0.00016, Val Loss = 0.00066
# Epoch 55: Train Loss = 0.00015, Val Loss = 0.00067
# Epoch 56: Train Loss = 0.00013, Val Loss = 0.00065
# Epoch 57: Train Loss = 0.00014, Val Loss = 0.00070
# Epoch 58: Train Loss = 0.00016, Val Loss = 0.00071
# Epoch 59: Train Loss = 0.00015, Val Loss = 0.00063
# Epoch 60: Train Loss = 0.00013, Val Loss = 0.00062
# Epoch 61: Train Loss = 0.00014, Val Loss = 0.00066
# Epoch 62: Train Loss = 0.00014, Val Loss = 0.00061
# Epoch 63: Train Loss = 0.00010, Val Loss = 0.00057
# Epoch 64: Train Loss = 0.00010, Val Loss = 0.00057
# Epoch 65: Train Loss = 0.00011, Val Loss = 0.00059
# Epoch 66: Train Loss = 0.00012, Val Loss = 0.00070
# Epoch 67: Train Loss = 0.00014, Val Loss = 0.00058
# Epoch 68: Train Loss = 0.00011, Val Loss = 0.00057
# Epoch 69: Train Loss = 0.00012, Val Loss = 0.00058
# Epoch 70: Train Loss = 0.00014, Val Loss = 0.00077
# Epoch 71: Train Loss = 0.00018, Val Loss = 0.00066
# Epoch 72: Train Loss = 0.00020, Val Loss = 0.00059
# Epoch 73: Train Loss = 0.00013, Val Loss = 0.00055
# Epoch 74: Train Loss = 0.00013, Val Loss = 0.00056
# Epoch 75: Train Loss = 0.00009, Val Loss = 0.00053
# Epoch 76: Train Loss = 0.00009, Val Loss = 0.00052
# Epoch 77: Train Loss = 0.00008, Val Loss = 0.00052
# Epoch 78: Train Loss = 0.00008, Val Loss = 0.00055
# Epoch 79: Train Loss = 0.00012, Val Loss = 0.00055
# Epoch 80: Train Loss = 0.00012, Val Loss = 0.00073
# Epoch 81: Train Loss = 0.00016, Val Loss = 0.00057
# Epoch 82: Train Loss = 0.00013, Val Loss = 0.00054
# Epoch 83: Train Loss = 0.00010, Val Loss = 0.00052
# Epoch 84: Train Loss = 0.00010, Val Loss = 0.00051
# Epoch 85: Train Loss = 0.00010, Val Loss = 0.00051
# Epoch 86: Train Loss = 0.00009, Val Loss = 0.00049
# Epoch 87: Train Loss = 0.00012, Val Loss = 0.00057
# Epoch 88: Train Loss = 0.00010, Val Loss = 0.00050
# Epoch 89: Train Loss = 0.00007, Val Loss = 0.00047
# Epoch 90: Train Loss = 0.00008, Val Loss = 0.00048
# Epoch 91: Train Loss = 0.00008, Val Loss = 0.00048
# Epoch 92: Train Loss = 0.00007, Val Loss = 0.00051
# Epoch 93: Train Loss = 0.00008, Val Loss = 0.00049
# Epoch 94: Train Loss = 0.00009, Val Loss = 0.00048
# Epoch 95: Train Loss = 0.00009, Val Loss = 0.00047
# Epoch 96: Train Loss = 0.00010, Val Loss = 0.00048
# Epoch 97: Train Loss = 0.00010, Val Loss = 0.00051
# Epoch 98: Train Loss = 0.00008, Val Loss = 0.00049
# Epoch 99: Train Loss = 0.00008, Val Loss = 0.00054
# Epoch 100: Train Loss = 0.00014, Val Loss = 0.00049
# Epoch 101: Train Loss = 0.00013, Val Loss = 0.00060
# Epoch 102: Train Loss = 0.00012, Val Loss = 0.00047
# Epoch 103: Train Loss = 0.00009, Val Loss = 0.00049
# Epoch 104: Train Loss = 0.00009, Val Loss = 0.00063
# Epoch 105: Train Loss = 0.00017, Val Loss = 0.00048
# Epoch 106: Train Loss = 0.00011, Val Loss = 0.00047
# Epoch 107: Train Loss = 0.00010, Val Loss = 0.00054
# Epoch 108: Train Loss = 0.00009, Val Loss = 0.00044
# Epoch 109: Train Loss = 0.00007, Val Loss = 0.00043
# Epoch 110: Train Loss = 0.00008, Val Loss = 0.00059
# Epoch 111: Train Loss = 0.00011, Val Loss = 0.00052
# Epoch 112: Train Loss = 0.00011, Val Loss = 0.00045
# Epoch 113: Train Loss = 0.00007, Val Loss = 0.00044
# Epoch 114: Train Loss = 0.00009, Val Loss = 0.00050
# Epoch 115: Train Loss = 0.00007, Val Loss = 0.00046
# Epoch 116: Train Loss = 0.00007, Val Loss = 0.00043
# Epoch 117: Train Loss = 0.00005, Val Loss = 0.00041
# Epoch 118: Train Loss = 0.00005, Val Loss = 0.00042
# Epoch 119: Train Loss = 0.00005, Val Loss = 0.00043
# Epoch 120: Train Loss = 0.00006, Val Loss = 0.00044
# Epoch 121: Train Loss = 0.00015, Val Loss = 0.00046
# Epoch 122: Train Loss = 0.00011, Val Loss = 0.00047
# Epoch 123: Train Loss = 0.00009, Val Loss = 0.00047
# Epoch 124: Train Loss = 0.00010, Val Loss = 0.00046
# Epoch 125: Train Loss = 0.00011, Val Loss = 0.00044
# Epoch 126: Train Loss = 0.00008, Val Loss = 0.00046
# Epoch 127: Train Loss = 0.00006, Val Loss = 0.00045
# Epoch 128: Train Loss = 0.00005, Val Loss = 0.00041
# Epoch 129: Train Loss = 0.00007, Val Loss = 0.00041
# Epoch 130: Train Loss = 0.00006, Val Loss = 0.00040
# Epoch 131: Train Loss = 0.00006, Val Loss = 0.00040
# Epoch 132: Train Loss = 0.00004, Val Loss = 0.00048
# Epoch 133: Train Loss = 0.00008, Val Loss = 0.00043
# Epoch 134: Train Loss = 0.00006, Val Loss = 0.00044
# Epoch 135: Train Loss = 0.00008, Val Loss = 0.00041
# Epoch 136: Train Loss = 0.00005, Val Loss = 0.00040
# Epoch 137: Train Loss = 0.00005, Val Loss = 0.00043
# Epoch 138: Train Loss = 0.00009, Val Loss = 0.00044
# Epoch 139: Train Loss = 0.00010, Val Loss = 0.00044
# Epoch 140: Train Loss = 0.00006, Val Loss = 0.00043
# Epoch 141: Train Loss = 0.00009, Val Loss = 0.00053
# Epoch 142: Train Loss = 0.00011, Val Loss = 0.00042
# Epoch 143: Train Loss = 0.00007, Val Loss = 0.00053
# Epoch 144: Train Loss = 0.00022, Val Loss = 0.00054
# Epoch 145: Train Loss = 0.00017, Val Loss = 0.00049
# Epoch 146: Train Loss = 0.00014, Val Loss = 0.00055
# Epoch 147: Train Loss = 0.00013, Val Loss = 0.00100
# Epoch 148: Train Loss = 0.00031, Val Loss = 0.00073
# Epoch 149: Train Loss = 0.00018, Val Loss = 0.00065
# Epoch 150: Train Loss = 0.00014, Val Loss = 0.00052
# Epoch 151: Train Loss = 0.00014, Val Loss = 0.00041
# Early stopping triggered.

# %% [markdown]
# ## 📊 Evaluation & Visualization

# %%
# === Load Best Model ===
model.load_state_dict(torch.load("best_model.pth", weights_only=True))

model.eval()

# === Evaluation Function ===
def evaluate_model(model, loader):
    """
    Evaluate the model on a given dataset loader.

    Args:
        model (nn.Module): Trained model.
        loader (DataLoader): DataLoader for evaluation.

    Returns:
        Tuple: (MSE, MAE, R², Ground Truths, Predictions)
    """
    model.eval()
    predictions = []
    ground_truths = []

    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch = X_batch.to(device)
            outputs = model(X_batch).cpu()
            predictions.append(outputs)
            ground_truths.append(y_batch)

    y_pred = torch.cat(predictions).numpy()
    y_true = torch.cat(ground_truths).numpy()

    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    return mse, mae, r2, y_true, y_pred

# === Evaluate on Test Set ===
mse, mae, r2, Y_true_np, Y_pred_np = evaluate_model(model, test_loader)
print(f"Test MSE: {mse:.5f}, MAE: {mae:.5f}, R² Score: {r2:.5f}")
# Out:
# Test MSE: 0.00029, MAE: 0.00926, R² Score: 0.99658

# %% [markdown]
# ## Prediction Visualization Function

# %%
# === Visualize Predictions ===
def show_predictions(X, Y_true, Y_pred, num_samples=5):
    """
    Display image samples with predicted and true coordinates.

    Args:
        X (Tensor): Input image data.
        Y_true (ndarray): True coordinates.
        Y_pred (ndarray): Predicted coordinates.
        num_samples (int): Number of samples to visualize.
    """
    for i in range(num_samples):
        img = X[i].squeeze().numpy()

        # Scale back from normalized [0,1] to [0,49] and convert to int
        pred_x, pred_y = (Y_pred[i] * 49).astype(int)
        true_x, true_y = (Y_true[i] * 49).astype(int)

        plt.imshow(img, cmap='gray')
        plt.scatter(true_x, true_y, color='lime', label='True', s=50)
        plt.scatter(pred_x, pred_y, color='red', label='Predicted', s=50)

        # Annotate values on the image
        plt.text(1, 3, f'True: ({true_x}, {true_y})', color='lime', fontsize=10, weight='bold')
        plt.text(1, 9, f'Pred: ({pred_x}, {pred_y})', color='red', fontsize=10, weight='bold')

        plt.title(f"Sample {i+1}")
        plt.legend(loc='upper right')
        plt.grid(False)
        plt.show()

# === Show Predictions ===
show_predictions(X_test, Y_true_np, Y_pred_np)

# %% [markdown]
# ##  Conclusion
#
# In this project, we trained a CNN model to accurately predict the position of a single white pixel in a black 50x50 image. We treated this as a regression task by outputting normalized (x, y) coordinates. Results show very low MSE and high R² scores, indicating the model learned the spatial localization effectively.
